# %%
import os, sys
import extraction_functions 
from pypdf import PdfReader
import pandas as pd
import re

pdfpath = "../../data/texts/bees-of-the-world.pdf"
text = PdfReader(pdfpath)

# %%
#section 33

p141 = extraction_functions.remove_before_after(text.pages[140].extract_text(), a_str = 'articu-')
p142 = extraction_functions.remove_before_after(text.pages[141].extract_text(), b_str = 'lation')
sec33 = p141 + " " + p142

sec33_nodes = extraction_functions.clean_df(extraction_functions.extract_keys(sec33), 'sec33')
sec33_term = extraction_functions.create_terminal_points(sec33_nodes)

sec33_term
# Out:
#       id                             description   parent final_node
# 0  sec75                            Megachilidae  sec33-2      False
# 1  sec85                                  Apidae  sec33-2      False
# 2  sec49  Andreninae and Panurginae (Andrenidae)  sec33-5      False
# 3  sec68                              Melittidae  sec33-5      False
# 4  sec60                   Oxaeinae (Andrenidae)  sec33-6      False
# 5  sec61                              Halictidae  sec33-6      False
# 6  sec36                           Stenotritidae  sec33-7      False
# 7  sec37                              Colletidae  sec33-7      False

# %%
#section 35
p146 = extraction_functions.remove_before_after(text.pages[145].extract_text(), b_str = '1. Scopa', a_str = '.. 13')
p147 = extraction_functions.remove_before_after(text.pages[146].extract_text(), b_str = '13(12).')
sec35 = p146 + " " + p147

sec35_nodes = extraction_functions.clean_df(extraction_functions.extract_keys(sec35), 'sec35')
sec35_term = extraction_functions.create_terminal_points(sec35_nodes)

sec35_term
# Out:
#         id                                        description   parent  \
# 0    sec46                        Xeromelissinae (Colletidae)  sec35-2
# 1    sec75                                       Megachilidae  sec35-3
# 2    sec50                        Alocandreninae (Andrenidae)  sec35-6
# 3    sec52                            Panurginae (Andrenidae)  sec35-6
# 4    sec51                            Andreninae (Andrenidae)  sec35-7
# 5    sec77                      Pararhophitini (Megachilidae)  sec35-8
# 6    sec62                            Rophitinae (Halictidae)  sec35-9
# 7    sec36                                      Stenotritidae  sec35-1
# 8    sec85                                             Apidae  sec35-1
# 9    sec68                                         Melittidae  sec35-1
# 10   sec51                            Andreninae (Andrenidae)  sec35-1
# 11   sec60  13 13(12). Stigma absent (Fig. 60-2a); two sub...  sec35-1
# 12   sec42                        Diphaglossinae (Colletidae)  sec35-1
# 13   sec63                              Nomiinae (Halictidae)  sec35-1
# 14   sec39                            Colletinae (Colletidae)  sec35-1
# 15   sec65                            Halictinae (Halictidae)  sec35-1
# 16   sec64                           Nomioidinae (Halictidae)  sec35-1
# 17   sec65  Cleptoparasites in Halictinae, both tribes  (H...  sec35-1
# 18   sec47                             Hylaeinae (Colletidae)  sec35-2
# 19   sec48                         Euryglossinae (Colletidae)  sec35-2
# 20   sec91                                 Nomadinae (Apidae)  sec35-2
# 21   sec79  Cleptoparasites in Megachilinae, all tribes  (...  sec35-2
# 22   sec90        Social parasites within Allodapini (Apidae)  sec35-2
# 23  sec102  Cleptoparasites and social parasites within Ap...  sec35-2
#
#    final_node
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False

# %%
#section 36
sec36 = extraction_functions.remove_before_after(text.pages[148].extract_text(), b_str = '1. T7', a_str = '..Stenotritus')

sec36_nodes = extraction_functions.clean_df(extraction_functions.extract_keys(sec36), 'sec36', term = True)
sec36_term = extraction_functions.create_terminal_points(sec36_nodes, term = True)

sec36_term
# Out:
#               id    description   parent final_node
# 0  Ctenocolletes  Ctenocolletes  sec36-1       True
# 1    Stenotritus    Stenotritus  sec36-1       True

# %%
#section 37
p153 = extraction_functions.remove_before_after(text.pages[152].extract_text(), b_str = '1. Body', a_str = 'one-third as wide')
p154 = extraction_functions.remove_before_after(text.pages[153].extract_text(), b_str = 'as long;', a_str = 'one-third as wide')
sec37 = p153 + " " + p154

sec37_nodes = extraction_functions.clean_df(extraction_functions.extract_keys(sec37), 'sec37')
sec37_term = extraction_functions.create_terminal_points(sec37_nodes)

sec37_nodes
# Out:
#         id                                          left_text left_target  \
# 0  sec37-1  Body usually hairy, female with well-formed sc...     sec37-2
# 1  sec37-2  Stigma small, shorter than prestigma, as wide ...       sec42
# 2  sec37-3  Facial fovea absent or broad, at least one-thi...       sec46
# 3  sec37-4  Supraclypeal area elevated abruptly above leve...       sec47
#
#                                           right_text  \
# 0  Body with hairs short and relatively sparse, f...
# 1  Stigma usually large, at least longer than pre...
# 2  Facial fovea usually a narrow groove, sometime...
# 3  Supraclypeal area sloping up from level of ant...
#
#                                         right_target left_target_info  \
# 0                                            sec37-3             None
# 1                                              sec38   Diphaglossinae
# 2                                            sec37-4   Xeromelissinae
# 3  Euryglossinae (Sec. 48) 37. Family Colletidae 135        Hylaeinae
#
#   right_target_info   parent
# 0              None      NaN
# 1        Colletinae  sec37-1
# 2              None  sec37-1
# 3              None  sec37-3

# %% [markdown]
# new approach:

# %%
key_txt = "../../data/texts/bees-of-the-world-keys.pdf"
pdf = PdfReader(key_txt)


start_end = pd.read_csv("../../data/maps/section_start_end.csv", encoding = "cp1252", nrows=408)
additional = pd.read_csv("../../data/maps/start_end_extra.csv", index_col = 'index')
pages = pd.concat([start_end, additional])
num = pages['new_page'].tolist()


for i in range(len(pages)):
    t = extraction_functions.remove_before_after(pdf.pages[num[i] - 1].extract_text(), pages.loc[i]['start'], pages.loc[i]['end'])
    pages.loc[i, 'text'] = t

# %%
pages = pd.read_csv('../../data/texts/bees-of-the-world-keys.csv', encoding = 'utf-8-sig').drop(columns=['index'])

sections = pages.groupby('section')['text'].apply(' '.join).reset_index()
sections['page_numbers'] = pages.groupby('section')['page'].apply(lambda x: list(x)).reset_index(drop = True)
